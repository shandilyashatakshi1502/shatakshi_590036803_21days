# %%
age =25
city = "dehradun"
print(age,city)


a = 10
print(type(a))

b = 10.5
print(type(b))

c = "10"
print(type(c))

d = True
print(type(d))

price = 499.9
print(type(price))

x = 10
print(x)
x = 20
print(20)

name = "python"
version = 3
print(name,version)

student_name = "shatakshi"
print(student_name)


# student_name, student2, _score are valid 
# whereas 2student,studet-name are in valid 


a = 5
b = 3
print(a+b)
print(a*b)

lenght = 10
width = 5
area = lenght * width 
print(area)


x = "10"
y = "20" 
print(x+y)


number = "25" 
result = int(number) + 5
print(result)



x = 10
y = float(x)
print(y)
print(type(y))




price = 99.5 
price_int = int(price) 
print(price_int)


a = 10
b = 3
print(a/b)
print(a//b)
print(a % b)


a = 10 
b = 20
c = 30
print(a,b,c)


x = 5
x = x + 10
x = x* 2
print(x)



item = "laptop" 
price = 50000
quantity = 2 
total_price = price*quantity 
print(total_price)


age = "20" 
next_age = int(age) + 1
print(next_age) 



student_name = "shatakshi" 
age = 20 
course = "python prgrammimg" 
subject1 = 85
subject2 = 75 
subject3 = 80 

total_marks = subject1 + subject2 + subject3 
average_marks = total_marks / 3 

print(student_name)
print(age)
print(course)
print(total_marks)
print(average_marks)
# Out:
#   Cell In[34], line 122
#     git add .
#         ^
# SyntaxError: invalid syntax

# %%
name = "shatakshi"
print(name)
# Out:
# shatakshi
