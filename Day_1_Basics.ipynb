# %%
print('hello python')
# Out:
# hello python

# %%
name = 'shatakshi'
print(name)
# Out:
# shatakshi

# %%
student = {'name' : 'asha' , 'age' : 20, 'skills'  : ['Python' , 'excel']}
print( student ['name'] , student ['skills'] [0], len(student['skills']))
# Out:
# asha Python 2

# %%
price = 250
quantity = 3
discount = 0.10
tax = 0.18
subtotal = price * quantity
total = subtotal * (1 - discount) * (1 + tax)
print(round(total, 2))
# Out:
# 796.5

# %%
price = 250
quantity = 3
print(price * quantity)
# Out:
# 750

# %%
total = 987.654
print(round(total, 2))
# Out:
# 987.65

# %%
text = 'python basics'
print(text.upper())
print(text.title())
# Out:
# PYTHON BASICS
# Python Basics

# %%
city = 'Bengaluru'
print(f'I live in {city}.')
# Out:
# I live in Bengaluru.

# %%
radius = 5 
pi = 3.14159 
area = pi * radius ** 2
circumference = 2 * pi * radius 
print({'area' : round(area, 2), 'circumference' : round(circumference, 2)})
# Out:
# {'area': 78.54, 'circumference': 31.42}

# %%
radius = 5 
area = 3.14 * radius ** 2
print(area)
# Out:
# 78.5
